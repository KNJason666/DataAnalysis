# %% [markdown]
# # 备注：f19011632詹康宁-月饼数据可视化分析

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pandas import Series, DataFrame
import openpyxl
import seaborn as sns
import pyecharts.charts as pyc
import pyecharts.options as opts
# 作图的字体默认设置
fontdict = {'fontsize': 15,'horizontalalignment': 'center'}
import matplotlib
font = {'family': 'Microsoft Yahei'}
matplotlib.rc('font', **font)

# %% [markdown]
# # 1.数据导入

# %%
df = pd.read_excel("MoonData.xlsx",engine="openpyxl")

# %%
df.head(2)
# Out:
#                                  title        shop      brand  price   sales  \
# 0                        诺梵中秋巧克力夹心月饼礼盒   诺梵京东自营旗舰店  诺梵（NOVOR）  109.0    5000
# 1  京东超市\t\n月饼 稻香村月饼礼盒中秋月饼蛋黄莲蓉上品御礼1080g  稻香村自营官方旗舰店        稻香村  129.0  200000
#
#   category city
# 0       其它   浙江
# 1       广式   北京

# %% [markdown]
# # 2.数据可视化

# %% [markdown]
# ## 2.1各省销售额

# %%
result1 = df.groupby(by=[df['city']])['sales'].sum()
total_sales_city = list(result1)
city = list(result1.index)

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

total_city = (
    Map()
    .add("销售额", [list(z) for z in zip(city,total_sales_city)], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="各地区销售额",subtitle="按省汇总"),
        visualmap_opts=opts.VisualMapOpts(split_number=10, is_piecewise=True,pieces=[
        #不指定 max，表示 max 为无限大（Infinity）。
        {"min": 10000000},
        {"min": 1000000, "max": 9999999},
        {"min": 100000, "max": 999999},
        {"min": 10000, "max": 99999},
        {"min": 1000, "max": 9999},
         #不指定 min，表示 min 为无限大（-Infinity）
        {"max": 999}],    
        )
    )
)
total_city.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="c49bb1e297554c63b31d06b330dafc2b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_c49bb1e297554c63b31d06b330dafc2b = echarts.init(
#                     document.getElementById('c49bb1e297554c63b31d06b330dafc2b'), 'white', {renderer: 'canvas'});
#                 var option_c49bb1e297554c63b31d06b330dafc2b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u9500\u552e\u989d",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 1024439
#                 },
#                 {
#                     "name": "\u4e1c\u839e",
#                     "value": 40200
#                 },
#                 {
#                     "name": "\u4e2d\u56fd",
#                     "value": 2320995
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 101853
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 4739503
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 2500
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 98
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 100100
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 11570151
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": 101600
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 1824600
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 20000
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 2032123
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 3000000
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 762400
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 2000
#                 },
#                 {
#                     "name": "\u7389\u6eaa",
#                     "value": 239
#                 },
#                 {
#                     "name": "\u77f3\u5bb6",
#                     "value": 500000
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 2110000
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 247500
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 120000
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 825000
#                 },
#                 {
#                     "name": "\u9ed1\u9f99",
#                     "value": 1731
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u552e\u989d"
#             ],
#             "selected": {
#                 "\u9500\u552e\u989d": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5404\u5730\u533a\u9500\u552e\u989d",
#             "subtext": "\u6309\u7701\u6c47\u603b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 10,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0,
#         "pieces": [
#             {
#                 "min": 10000000
#             },
#             {
#                 "min": 1000000,
#                 "max": 9999999
#             },
#             {
#                 "min": 100000,
#                 "max": 999999
#             },
#             {
#                 "min": 10000,
#                 "max": 99999
#             },
#             {
#                 "min": 1000,
#                 "max": 9999
#             },
#             {
#                 "max": 999
#             }
#         ]
#     }
# };
#                 chart_c49bb1e297554c63b31d06b330dafc2b.setOption(option_c49bb1e297554c63b31d06b330dafc2b);
#         });
#     </script>

# %% [markdown]
# >分析：其中广东的总销售额最大，为11570151元

# %% [markdown]
# ## 2.2销售额前十店铺

# %%
df2 = df
result4 = df2.groupby(by=[df['shop']])['sales'].sum()
result4 = Series.sort_values(result4)
result4 = result4.tail(10)
total_sales_shop = list(result4)
shop = list(result4.index)

# %%
import pyecharts.options as opts
from pyecharts.charts import Pie

data_pair = [list(z) for z in zip(shop, total_sales_shop)]
data_pair.sort(key=lambda x: x[1])
shop_sales = (
    Pie(init_opts=opts.InitOpts(width="1600px", height="800px", bg_color="#2c343c"))
    .add(
        series_name="销售额",
        data_pair=data_pair,
        rosetype="radius",
        radius="50%",
        center=["50%", "50%"],
        label_opts=opts.LabelOpts(is_show=False, position="center"),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="各个店铺销售额",
            pos_left="center",
            pos_top="20",
            title_textstyle_opts=opts.TextStyleOpts(color="#fff"),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item", formatter="{a} <br/>{b}: {c} ({d}%)"
        ),
        label_opts=opts.LabelOpts(color="rgba(255, 255, 255, 0.3)"),
    ) 
)
shop_sales.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2edd050c2b234d5cacc435f6e132c798" style="width:1600px; height:800px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2edd050c2b234d5cacc435f6e132c798 = echarts.init(
#                     document.getElementById('2edd050c2b234d5cacc435f6e132c798'), 'white', {renderer: 'canvas'});
#                 var option_2edd050c2b234d5cacc435f6e132c798 = {
#     "backgroundColor": "#2c343c",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u9500\u552e\u989d",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u91d1\u5c0a\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                     "value": 1120000
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u9152\u5bb6\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                     "value": 1140200
#                 },
#                 {
#                     "name": "\u7f8e\u5fc3\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                     "value": 1205000
#                 },
#                 {
#                     "name": "\u826f\u54c1\u94fa\u5b50\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                     "value": 1400000
#                 },
#                 {
#                     "name": "\u4e94\u82b3\u658b\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                     "value": 1755000
#                 },
#                 {
#                     "name": "\u53cb\u81e3\uff08YOUCHEN\uff09\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                     "value": 1900000
#                 },
#                 {
#                     "name": "\u4eac\u4e1c\u81ea\u8425\u6708\u997c\u6d3b\u52a8\u4e13\u533a",
#                     "value": 2510300
#                 },
#                 {
#                     "name": "\u820c\u91cc\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                     "value": 3000000
#                 },
#                 {
#                     "name": "\u7a3b\u9999\u6751\u81ea\u8425\u5b98\u65b9\u65d7\u8230\u5e97",
#                     "value": 4410019
#                 },
#                 {
#                     "name": "\u534e\u7f8e\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                     "value": 6750000
#                 }
#             ],
#             "radius": "50%",
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": "rgba(255, 255, 255, 0.3)",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u91d1\u5c0a\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                 "\u5e7f\u5dde\u9152\u5bb6\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                 "\u7f8e\u5fc3\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                 "\u826f\u54c1\u94fa\u5b50\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                 "\u4e94\u82b3\u658b\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                 "\u53cb\u81e3\uff08YOUCHEN\uff09\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                 "\u4eac\u4e1c\u81ea\u8425\u6708\u997c\u6d3b\u52a8\u4e13\u533a",
#                 "\u820c\u91cc\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97",
#                 "\u7a3b\u9999\u6751\u81ea\u8425\u5b98\u65b9\u65d7\u8230\u5e97",
#                 "\u534e\u7f8e\u4eac\u4e1c\u81ea\u8425\u65d7\u8230\u5e97"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5404\u4e2a\u5e97\u94fa\u9500\u552e\u989d",
#             "left": "center",
#             "top": "20",
#             "padding": 5,
#             "itemGap": 10,
#             "textStyle": {
#                 "color": "#fff"
#             }
#         }
#     ]
# };
#                 chart_2edd050c2b234d5cacc435f6e132c798.setOption(option_2edd050c2b234d5cacc435f6e132c798);
#         });
#     </script>

# %% [markdown]
# >可以从图中看出，销售额前三的店铺分别是华美京东自营旗舰店、稻香村自营官方旗舰店、舌里京东自营旗舰店

# %% [markdown]
# ## 2.3各种类月饼销售额

# %%
result2 = df.groupby(by=[df['category']])['sales'].sum()
total_sales_category = list(result2)
category = list(result2.index)

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.charts import Line
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType

total_category = (
     Bar()
    .add_xaxis(category)
    .add_yaxis("销售额",total_sales_category)
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="各种类月饼销售额"),
    )
     .set_series_opts(label_opts=opts.LabelOpts(is_show=False),
    markpoint_opts=opts.MarkPointOpts(
    data=[
    opts.MarkPointItem(type_="max", name="最⼤值"),
    opts.MarkPointItem(type_="min", name="最⼩值"),
    ]))
)
total_category.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="27658d59a50b4377ad0c74badd4472b8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_27658d59a50b4377ad0c74badd4472b8 = echarts.init(
#                     document.getElementById('27658d59a50b4377ad0c74badd4472b8'), 'white', {renderer: 'canvas'});
#                 var option_27658d59a50b4377ad0c74badd4472b8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9500\u552e\u989d",
#             "legendHoverLink": true,
#             "data": [
#                 224628,
#                 5659836,
#                 2072,
#                 171897,
#                 129000,
#                 79625,
#                 15688227,
#                 1927683,
#                 123250,
#                 5245,
#                 2992336
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u2f24\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u2f29\u503c",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u552e\u989d"
#             ],
#             "selected": {
#                 "\u9500\u552e\u989d": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -15,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4eac\u5f0f",
#                 "\u5176\u5b83",
#                 "\u51b0\u6dc7",
#                 "\u51b0\u76ae",
#                 "\u5361\u5238",
#                 "\u53f0\u5f0f",
#                 "\u5e7f\u5f0f",
#                 "\u6e2f\u5f0f",
#                 "\u6ec7\u5f0f",
#                 "\u6f6e\u5f0f",
#                 "\u82cf\u5f0f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u79cd\u7c7b\u6708\u997c\u9500\u552e\u989d",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_27658d59a50b4377ad0c74badd4472b8.setOption(option_27658d59a50b4377ad0c74badd4472b8);
#         });
#     </script>

# %% [markdown]
# >分析：可以看出，广式月饼的销售额最高，其次是苏式月饼和港式月饼,最大销售额6992，最小销售额2072

# %% [markdown]
# ## 2.4各种类销量

# %%
#利用销售额和单价计算出销量
df.eval('salesVolume = sales/price' , inplace=True)
df.head(2)
# Out:
#                                  title        shop      brand  price   sales  \
# 0                        诺梵中秋巧克力夹心月饼礼盒   诺梵京东自营旗舰店  诺梵（NOVOR）  109.0    5000
# 1  京东超市\t\n月饼 稻香村月饼礼盒中秋月饼蛋黄莲蓉上品御礼1080g  稻香村自营官方旗舰店        稻香村  129.0  200000
#
#   category city  salesVolume
# 0       其它   浙江    45.871560
# 1       广式   北京  1550.387597

# %%
result3 = df.groupby(by=[df['category']])['salesVolume'].sum()
total_salesVolume_category = list(result3)
category = list(result3.index)

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
from pyecharts.faker import Faker


total_category_num = (
    Line()
    .add_xaxis(category)
    .add_yaxis("销量", total_salesVolume_category, is_smooth=True)
    .set_series_opts(
        areastyle_opts=opts.AreaStyleOpts(opacity=0.5),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="各种类月饼销量"),
        xaxis_opts=opts.AxisOpts(
            axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
            is_scale=False,
            boundary_gap=False,
        ),
    )
)
total_category_num.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8efea84d12c94068958cdfdd9740f16e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8efea84d12c94068958cdfdd9740f16e = echarts.init(
#                     document.getElementById('8efea84d12c94068958cdfdd9740f16e'), 'white', {renderer: 'canvas'});
#                 var option_8efea84d12c94068958cdfdd9740f16e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u9500\u91cf",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u4eac\u5f0f",
#                     6139.211447331711
#                 ],
#                 [
#                     "\u5176\u5b83",
#                     158452.5925000277
#                 ],
#                 [
#                     "\u51b0\u6dc7",
#                     53.135962744680846
#                 ],
#                 [
#                     "\u51b0\u76ae",
#                     1839.4153638223281
#                 ],
#                 [
#                     "\u5361\u5238",
#                     208.37170324111878
#                 ],
#                 [
#                     "\u53f0\u5f0f",
#                     551.2183960746066
#                 ],
#                 [
#                     "\u5e7f\u5f0f",
#                     233643.48378688787
#                 ],
#                 [
#                     "\u6e2f\u5f0f",
#                     8196.480873069635
#                 ],
#                 [
#                     "\u6ec7\u5f0f",
#                     1843.6959492917326
#                 ],
#                 [
#                     "\u6f6e\u5f0f",
#                     45.36184210526316
#                 ],
#                 [
#                     "\u82cf\u5f0f",
#                     49303.50607079402
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u91cf"
#             ],
#             "selected": {
#                 "\u9500\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": true,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4eac\u5f0f",
#                 "\u5176\u5b83",
#                 "\u51b0\u6dc7",
#                 "\u51b0\u76ae",
#                 "\u5361\u5238",
#                 "\u53f0\u5f0f",
#                 "\u5e7f\u5f0f",
#                 "\u6e2f\u5f0f",
#                 "\u6ec7\u5f0f",
#                 "\u6f6e\u5f0f",
#                 "\u82cf\u5f0f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u79cd\u7c7b\u6708\u997c\u9500\u91cf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8efea84d12c94068958cdfdd9740f16e.setOption(option_8efea84d12c94068958cdfdd9740f16e);
#         });
#     </script>

# %% [markdown]
# >分析：可以看出，广式月饼的销量最高，其次是苏式月饼

# %% [markdown]
# # 3.数据大屏

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar,Map,Line, Page, Pie
from pyecharts.commons.utils import JsCode
from pyecharts.components import Table
from pyecharts.faker import Faker

# %%
def total_city()->Map:
    total_city = (
        Map()
        .add("销售额", [list(z) for z in zip(city,total_sales_city)], "china")
        .set_global_opts(
            title_opts=opts.TitleOpts(title="各地区销售额",subtitle="按省汇总"),
            visualmap_opts=opts.VisualMapOpts(split_number=10, is_piecewise=True,pieces=[
            #不指定 max，表示 max 为无限大（Infinity）。
            {"min": 10000000},
            {"min": 1000000, "max": 9999999},
            {"min": 100000, "max": 999999},
            {"min": 10000, "max": 99999},
            {"min": 1000, "max": 9999},
             #不指定 min，表示 min 为无限大（-Infinity）
            {"max": 999}],    
            )
        )
    )
    return total_city

def shop_sales()->Pie:
    shop_sales = (
    Pie(init_opts=opts.InitOpts(width="1600px", height="800px", bg_color="#2c343c"))
    .add(
        series_name="销售额",
        data_pair=data_pair,
        rosetype="radius",
        radius="50%",
        center=["50%", "50%"],
        label_opts=opts.LabelOpts(is_show=False, position="center"),
        )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="各个店铺销售额",
            pos_left="center",
            pos_top="20",
            title_textstyle_opts=opts.TextStyleOpts(color="#fff"),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
        )
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item", formatter="{a} <br/>{b}: {c} ({d}%)"
        ),
        label_opts=opts.LabelOpts(color="rgba(255, 255, 255, 0.3)"),
        ) 
    )
    return shop_sales

def total_category()->Bar:
    total_category = (
     Bar()
    .add_xaxis(category)
    .add_yaxis("销售额",total_sales_category)
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="各种类月饼销售额"),
        )
    )
    return total_category

def total_category_num()->Line:
	total_category_num = (
		Line()
		.add_xaxis(category)
		.add_yaxis("销量", total_salesVolume_category, is_smooth=True)
		.set_series_opts(
			areastyle_opts=opts.AreaStyleOpts(opacity=0.5),
			label_opts=opts.LabelOpts(is_show=False),
		)
		.set_global_opts(
			title_opts=opts.TitleOpts(title="各种类月饼销量"),
			xaxis_opts=opts.AxisOpts(
				axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
				is_scale=False,
				boundary_gap=False,
			),
		)
	)
	return total_category_num

# %%
page = Page(layout=Page.DraggablePageLayout, page_title="月饼数据可视化分析")
# 在页面中添加图表
page.add(
    total_city(),
    shop_sales(),
    total_category(),
    total_category_num(),)
page.render('test.html')
# Out:
# 'C:\\Users\\Soulyou\\Desktop\\付倩超_数据预处理\\期末报告数据及要求\\test.html'
